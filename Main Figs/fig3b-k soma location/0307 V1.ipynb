# %%
fig.write_image(r'D:\python\ploty\spx.pdf',scale = 20)

# %%
import plotly.graph_objects as go
import pandas as pd
import sys,os,json
sys.path.append(r"D:\python\core")
import visualization as vs
from brain_area import BrainArea
ba = BrainArea()

# %%
os.chdir(r"H:\20231030_figs\20231212_Soma_subtype4")

# %%
os.chdir(r"H:\20231218_figs\20231221_subtype2_Nts_soma3D")

# %%
dfsoma = pd.read_excel(r"all_soma_infor_1128_cluster.xlsx",index_col=0)

# %%
dfneuron = pd.read_csv("Subtype22_fig3_neuron_soma_infor.csv",index_col=0)

# %%
dfneuron
# Out:
#                      cluster     neurons location  geno           AP  \
# 201225_078_Nts_MMl        22  201225_078      MMl   Nts  7818.558594
# 202562_021_Tac2_MMl       22  202562_021      MMl  Tac2  8125.148438
# 202562_023_Tac2_MMl       22  202562_023      MMl  Tac2  8203.378906
# 202562_024_Tac2_MMl       22  202562_024      MMl  Tac2  8253.640625
# 202562_025_Tac2_MMl       22  202562_025      MMl  Tac2  8287.261719
# ...                      ...         ...      ...   ...          ...
# 211889_062_Pdyn_MMl       22  211889_062      MMl  Pdyn  7853.218750
# 211889_077_Pdyn_MMl       22  211889_077      MMl  Pdyn  8127.449219
# 211889_078_Pdyn_SUM       22  211889_078      SUM  Pdyn  7962.199219
# 211889_136_Pdyn_MMl       22  211889_136      MMl  Pdyn  8173.328125
# 211889_137_Pdyn_MMd       22  211889_137      MMd  Pdyn  8099.449219
#
#                               DV           ML
# 201225_078_Nts_MMl   5934.171875  5116.339844
# ...

# %%
dfsomaplot = dfsoma.loc[dfneuron.index.tolist()]
dfsomaplot.to_csv("Subtype22_fig3_neuron_soma_infor.csv")

# %%
dfsomaplot = pd.read_csv("Subtype2_fig3_neuron_soma_infor.csv",index_col=0)

# %%
dftmp = pd.read_csv("all_Subtype4_MS_Subtype1_soma_infor.csv",index_col=0)

# %%
dfsomaplot = dfneuron

# %%
# add color
geno = dfsomaplot.geno.value_counts().index.to_list()
color = ["red","cyan","navy","darkgray","darkgray","darkgray"]
color_dict = dict(zip(geno,color))
dfsomaplot["color"] = dfsomaplot.geno.map(color_dict)

# %%
dfsomaplot
# Out:
#                      cluster     neurons location  geno           AP  \
# 201225_078_Nts_MMl        22  201225_078      MMl   Nts  7818.558594
# 202562_021_Tac2_MMl       22  202562_021      MMl  Tac2  8125.148438
# 202562_023_Tac2_MMl       22  202562_023      MMl  Tac2  8203.378906
# 202562_024_Tac2_MMl       22  202562_024      MMl  Tac2  8253.640625
# 202562_025_Tac2_MMl       22  202562_025      MMl  Tac2  8287.261719
# ...                      ...         ...      ...   ...          ...
# 211889_062_Pdyn_MMl       22  211889_062      MMl  Pdyn  7853.218750
# 211889_077_Pdyn_MMl       22  211889_077      MMl  Pdyn  8127.449219
# 211889_078_Pdyn_SUM       22  211889_078      SUM  Pdyn  7962.199219
# 211889_136_Pdyn_MMl       22  211889_136      MMl  Pdyn  8173.328125
# 211889_137_Pdyn_MMd       22  211889_137      MMd  Pdyn  8099.449219
#
#                               DV           ML     color
# 201225_078_Nts_MMl   5934.171875  5116.339844      navy
# ...

# %%
dfneuron = dftmp.loc[(dftmp.geno =="Penk")&(dftmp.location.isin(['NDB', 'MS', 'HY', 'MPO', 'AVPV', 'AVP','ADP']))]

dfsomaplot = dfneuron.loc[~dfneuron.index.isin(["202168_016_Penk_NDB","210006_001_Penk_MS","210006_001_Penk_MS"])]

# %%
# subtype base
from matplotlib.lines import Line2D
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
plt.rc("font",family="Arial")

legend_elements = []
# for i in range(1,5):
for i in color_dict:
    legend_elements.append(Line2D([0], [0], marker='o', color="w", label=i,
                          markerfacecolor=color_dict[i], markersize=10))
fig, ax = plt.subplots()
ax.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.axis('off')
ax.legend(handles=legend_elements, loc='center')

plt.savefig(r"H:\20231218_figs\20231221_subtype22_terminal\lengend.pdf")

# %%
color_dict
# Out:
# {'Adcyap1': 'red',
#  'Tac2': 'cyan',
#  'Nts': 'navy',
#  'Pdyn': 'darkgray',
#  'Penk': 'darkgray',
#  'Tac1': 'darkgray'}

# %%
dfdata = pd.read_excel("all_soma_infor_20230914.xlsx",index_col =0)

# %%
dffc = pd.read_csv("somas_log2FC.csv",index_col=0,sep=",")

# %%
dfsomaplot[["AP","DV","ML"]]
# Out:
#                               AP           DV           ML
# 201225_078_Nts_MMl   7818.558594  5934.171875  5116.339844
# 201232_056_Tac1_MMm  7942.039062  6045.750000  5523.058594
# 201232_058_Tac1_MMm  8076.589844  6119.519531  5528.269531
# 201232_059_Tac1_MMm  8043.371094  6119.359375  5564.410156
# 202562_021_Tac2_MMl  8125.148438  6333.601562  5129.511719
# ...                          ...          ...          ...
# 211889_062_Pdyn_MMl  7853.218750  5999.148438  5182.531250
# 211889_077_Pdyn_MMl  8127.449219  6156.308594  5028.628906
# 211889_078_Pdyn_SUM  7962.199219  5847.339844  5135.371094
# 211889_136_Pdyn_MMl  8173.328125  6162.371094  5137.808594
# 211889_137_Pdyn_MMd  8099.449219  5829.039062  5426.050781
#
# [92 rows x 3 columns]

# %%
len(dfsomaplot)
# Out:
# 51

# %%
vols = []
vols.append(vs.generate_go_ba_qiu(r"D:\projectome\mouse_region_obj_left\795_left.obj",o=0.3,c="gray"))
fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    layout = vs.generate_go_layout(title="",eye_from=eyes)
    fig.layout = layout
    # fig.write_image('soma_plot2_%s.pdf'%(eyes),scale =8)
    fig.write_image('soma_plot2_%s.jpg'%(eyes),scale =8)
# Out:
# specified material (mtl1)  not loaded!

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut2",str(file)+"_cut_1.obj")
    return filepath
vols = []
vols.append(vs.generate_go_ba("STN",o=0.3,c="lightgray",half=True))
vols.append(vs.generate_go_ba("PSTN",o=0.3,c="lightgray",half=True))
# vols.append(vs.generate_go_ba("root",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("LM",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("MM",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("SUM",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("MBO",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("MS",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("MPO",o=0.3,c="lightgray",half=False))
# vols.append(vs.generate_go_ba("NDB",o=0.3,c="lightgray",half=False))

vols.append(vs.generate_go_scatters(dfsomaplot[["AP","DV","ML"]].values,size=2,color = "navy"))
# vols.append(vs.generate_go_scatters(dfsomaplot[["AP","DV","ML"]].values,size=2,color = dfsomaplot["color"].tolist()))
fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    layout = vs.generate_go_layout(title="",eye_from=eyes,big=2)
    fig.layout = layout
    # fig.write_image(r'soma_plot2_%s.pdf'%(eyes),scale =8)
    fig.write_image(r'soma_plot4_%s_new.jpg'%(eyes),scale =8)
# Out:
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut2",str(file)+"_cut_1.obj")
    return filepath
vols = []

vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="red"))
vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="lightgray"))

dfdata2 = dfdata.loc[dfdata.geno == markers]
vols.append(vs.generate_go_scatters(dfdata2[["AP","DV","ML"]].values,size=1,color="black"))

fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    layout = vs.generate_go_layout(title="",eye_from=eyes)
    fig.layout = layout
    fig.write_image(r'soma_plot2_%s_%s.pdf'%(markers,eyes),scale =8)
    fig.write_image(r'soma_plot2_%s_%s.jpg'%(markers,eyes),scale =8)

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut2",str(file)+"_cut_2.obj")
    return filepath

areas = ["HY"]
for i in range(12,13):
    vols = []
    vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.5,c="lightgray"))

# add area infor
    area = dffc.loc[dffc[str(i)]==dffc[str(i)].max(),:].index[0]
    area = "ARH"
    if area != "HY":
        vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="cyan"))

    dfdata2 = dfdata.loc[dfdata.cluster == i]
    vols.append(vs.generate_go_scatters(dfdata2[["AP","DV","ML"]].values,size=1,color="black"))

    fig = go.Figure(vols)
    for eyes in ["front","left","top","se"]:
        layout = vs.generate_go_layout(title="",eye_from=eyes)
        fig.layout = layout
        # fig.write_image(r'soma_plot2_%s_%s.pdf'%(i,eyes),scale =8)
        fig.write_image('figs\\cluster_%d_%s.jpg'%(i,eyes),scale =8)
# Out:
# specified material (mtl1)  not loaded!

# %%
# 不加enrich area
areas = ["HY"]
for i in range(1,32):
    vols = []
    # vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.5,c="lightgray"))
    vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="gray"))

# # add area infor
#     area = dffc.loc[dffc[str(i)]==dffc[str(i)].max(),:].index[0]
#     area = "ARH"
#     if area != "HY":
#         vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="cyan"))

    dfdata2 = dfdata.loc[dfdata.cluster == i]
    vols.append(vs.generate_go_scatters(dfdata2[["AP","DV","ML"]].values,size=1,color="black"))

    fig = go.Figure(vols)
    for eyes in ["front","left","top","se"]:
        layout = vs.generate_go_layout(title="",eye_from=eyes)
        fig.layout = layout
        # fig.write_image(r'soma_plot2_%s_%s.pdf'%(i,eyes),scale =8)
        fig.write_image('figs\\cluster_%d_%s.jpg'%(i,eyes),scale =8)
# Out:
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# specified material (mtl1)  not loaded!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d9d7bd59315a> in <module>
#      20         fig.layout = layout
#      21         # fig.write_image(r'soma_plot2_%s_%s.pdf'%(i,eyes),scale =8)
# ---> 22         fig.write_image('figs\\cluster_%d_%s.jpg'%(i,eyes),scale =8)
#
# ~\AppData\Local\Programs\Python\Python37\Lib\site-packages\plotly\basedatatypes.py in write_image(self, *args, **kwargs)
#    3804         import plotly.io as pio
#    3805
# -> 3806         return pio.write_image(self, *args, **kwargs)
#    3807
# ...

# %%
# %reset

# %%
markers = "Orexin"

# %%
os.chdir(r"H:\20231030_figs\20231108_soma_infor")

# %%
dfdata = pd.read_excel("enrich_0909_MBO.xlsx",index_col =0)

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut1",str(file)+"_cut_1.obj")
    return filepath
vols = []
for area in areas:
    vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="red"))
vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("root")[-1],o=0.3,c="lightgray"))

dfdata2 = dfdata.loc[dfdata.geno == markers]
vols.append(vs.generate_go_scatters(dfdata2[["AP","DV","ML"]].values,size=1,color="black"))

fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    layout = vs.generate_go_layout(title="",eye_from=eyes)
    fig.layout = layout
    fig.write_image(r'soma_plot2_%s_%s.pdf'%(markers,eyes),scale =8)
    fig.write_image(r'soma_plot2_%s_%s.jpg'%(markers,eyes),scale =8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-65cab8ed5fc7> in <module>
#       4     return filepath
#       5 vols = []
# ----> 6 for area in areas:
#       7     vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="red"))
#       8 vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("root")[-1],o=0.3,c="lightgray"))
#
# NameError: name 'areas' is not defined

# %%
DataPath = r"E:\20220210_for_figs\ploty soma plot"
dfcluster = pd.read_excel(os.path.join(DataPath,"cluster30_level_7.xlsx"),index_col=0)

# %%
dflong = pd.read_excel("all_soma_infor_MBO.xlsx")

# %%
dfdata = dflong.set_index("file")

# %%
from collections import Counter
tmp = dict(Counter(dfcluster.location2.to_list()))
dftmp = pd.DataFrame(sorted(tmp.items(), key=lambda item:item[1], reverse=True))
dftmp.columns = ["areas","counts"]
areasplot = dftmp.areas.tolist()[1:16]

# %%
from collections import Counter
import json

# %%
areadic = {}
for i,df in dfdata.groupby("geno"):
    tmp = dict(Counter(df.loaction2.to_list()))
    dftmp = pd.DataFrame(sorted(tmp.items(), key=lambda item:item[1], reverse=True))
    dftmp.columns = ["areas","counts"]
    areasplot = dftmp.areas.tolist()[0:16]
    if "HY" in areasplot:
        areasplot.remove("HY")
    areadic[df.geno.to_list()[0]] = areasplot
with open("area_infor.json", 'w', encoding='utf-8') as fw:
    json.dump(areadic, fw, indent=4, ensure_ascii=False)

# %%
with open("area_infor.json", 'w', encoding='utf-8') as fw:
    json.dump(areadic, fw, indent=4, ensure_ascii=False)

# %%
with open("area_infor jzl1.json", 'r+', encoding='utf-8') as fw:
    areadic = json.load(fw)

areadic

# %%
areasplot

# %%
dfdata

# %%
ba.search_brain_area_obj("HY")

# %%
dfdata
# Out:
#                               AP           DV           ML  cluster  \
# file
# 192710_002_Pomc_TU   6598.750000  6952.949219  4796.421875        1
# 192710_003_Pomc_TU   6530.761719  7075.410156  5187.261719       29
# 192710_004_Pomc_TU   6957.710938  7148.679688  4923.238281        9
# 192710_005_Pomc_TU   7142.988281  6960.210938  4757.390625       12
# 192710_007_Pomc_PMv  7676.769531  6479.488281  4958.589844       15
# ...                          ...          ...          ...      ...
# 220102_131_Crh_VMH   6861.308594  6518.140625  5569.441406       14
# 220102_139_Crh_DMH   7114.500000  6008.890625  5458.941406       25
# 220102_147_Crh_HY    6234.511719  5472.929688  5268.968750        6
# 220102_148_Crh_HY    6161.800781  5455.570312  5187.238281        8
# 220102_149_Crh_DMH   7039.000000  5891.679688  5306.761719       23
#
#                         neurons                 name soma   cre somas  \
# file
# ...

# %%
# generate count areas
from collections import Counter
tmp = dict(Counter(dfdata.somas.to_list()))
dftmp = pd.DataFrame(sorted(tmp.items(), key=lambda item:item[1], reverse=True))
dftmp.columns = ["areas","counts"]
areasplot = dftmp.areas.tolist()[1:16]

# %%
dftmp
# Out:
#    areas  counts
# 0     HY    1316
# 1    LHA     913
# 2    VMH     631
# 3    AHN     402
# 4     PH     400
# 5    PVH     399
# 6    MBO     358
# 7     TU     292
# 8    MPO     280
# 9    DMH     249
# 10   ARH     229
# 11   MPN     207
# 12    ZI     200
# 13  PVHd     184
# 14   PMv     158
# 15   LPO     135
# 16   PeF     120
# 17  PSTN      81
# 18   PMd      76
# 19   PVp      73
# 20   RCH      61
# 21    fx      52
# 22   AVP      49
# 23  SBPV      47
# 24   nst      32
# 25   STN      32
# 26  VMPO      25
# 27  AVPV      20
# 28    ME      14
# 29   ADP      13
# 30    PS      12
# 31    SO      12
# 32   PVi      11
# 33  VLPO      11
# 34   och      11
# 35   mtt      10
# 36   mfb       9
# 37   PVa       7
# 38    PD       6
# 39  MEPO       6
# 40   PST       6
# 41   opt       5
# 42   sup       5
# 43    pm       4
# 44    sm       4
# 45   SCH       4
# 46   ASO       3
# 47   mtg       2
# 48   int       2
# 49  PVpo       2

# %%
areasplot
# Out:
# ['LHA',
#  'VMH',
#  'AHN',
#  'PH',
#  'PVH',
#  'MBO',
#  'TU',
#  'MPO',
#  'DMH',
#  'ARH',
#  'MPN',
#  'ZI',
#  'PVHd',
#  'PMv',
#  'LPO']

# %%
color = ['red','green','blue', 'cyan', 'magenta', 'yellow',"brown","darkred","gray","navy","orange","skyblue","gold","tomato","teal"]

# %%
color_dic = {}
for i,j in zip(areasplot,color):
    color_dic[i] = j

# %%
with open("color_dic.json", 'w', encoding='utf-8') as fw:
    json.dump(color_dic, fw, indent=4, ensure_ascii=False)

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut1",str(file)+"_cut_1.obj")
    return filepath

vols = []
for area,cl in zip(areasplot,color):
    vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c=cl))
vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="gray"))

# %%
for loc,dfnew in dfdata.groupby("loaction2"):
    for area,cl in zip(areasplot,color):
        if loc == area:
            # print(cl)
            vols.append(vs.generate_go_scatters(dfnew[["AP","DV","ML"]].values,size=1,name=area,color=cl,showlegend=True))

# %%
fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    layout = vs.generate_go_layout(title="",eye_from=eyes)
    fig.layout = layout
    fig.write_image(r'soma_plot_v2_%s.pdf'%(eyes),scale =8)
    fig.write_image(r'soma_plot_v2_%s.jpg'%(eyes),scale =8)

# %%
# for seperate plot MBO
with open("area_infor jzl.json", 'r+', encoding='utf-8') as fw:
    areadic = json.load(fw)

# %%
dfdata.loc[dfdata.geno == "Pomc"]

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut1",str(file)+"_cut_1.obj")
    return filepath

for markers in areadic:
    areas = areadic[markers]

    vols = []
    for area in areas:
        vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c=color_dic[area]))
    vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="gray"))
    
    dfdata2 = dfdata.loc[dfdata.geno == markers]
    vols.append(vs.generate_go_scatters(dfdata2[["AP","DV","ML"]].values,size=1,color="black"))

    fig = go.Figure(vols)
    for eyes in ["front","left","top","se"]:
        layout = vs.generate_go_layout(title="",eye_from=eyes)
        fig.layout = layout
        fig.write_image(r'soma_plot_%s_%s.pdf'%(markers,eyes),scale =8)
        fig.write_image(r'soma_plot_%s_%s.jpg'%(markers,eyes),scale =8)

# %%
vols = []
for area,cl in zip(areasplot,color):
    vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c=cl))
vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="gray"))

# %%
# for long range
dflong = dfcluster[dfcluster.cluster<12]

# %%
# generate count areas
from collections import Counter
tmp = dict(Counter(dfcluster.location2.to_list()))
dftmp = pd.DataFrame(sorted(tmp.items(), key=lambda item:item[1], reverse=True))
dftmp.columns = ["areas","counts"]
areasplot = dftmp.areas.tolist()[1:16]

# %%
color = ['red','green','blue', 'cyan', 'magenta', 'yellow',"brown","darkred","gray","navy","orange"]

# %%
areasplot = ["LHA"]

# %%
def get_the_obj_path(area):
    file = ba.search_brain_area(area)[-1][0]
    filepath = os.path.join(r"D:\projectome\HY obj\cut1",str(file)+"_cut_1.obj")
    print(filepath)
    return filepath

vols = []
for area in areasplot:
    vols.append(vs.generate_go_ba_qiu(get_the_obj_path(area),o=0.3,c="gray"))
vols.append(vs.generate_go_ba_qiu(ba.search_brain_area_obj("HY")[-1],o=0.3,c="white"))
# Out:
# specified material (mtl1)  not loaded!
# D:\projectome\HY obj\cut1\194_cut_1.obj

# %%
fig = go.Figure(vols)
for eyes in ["front","left","top","se"]:
    
    layout = vs.generate_go_layout(title="",eye_from=eyes)
    fig.layout = layout
    fig.write_image(r'E:\20220210_for_figs\0715 figs\fig2\cluster_plot_v2_%s.pdf'%(eyes),scale =8)
    fig.write_image(r'E:\20220210_for_figs\0715 figs\fig2\cluster_plot_v2_%s.jpg'%(eyes),scale =8)

# %%
loc

# %%
fig = go.Figure(vols)
layout = vs.generate_go_layout(title="",eye_from="se")
fig.layout = layout
fig.show()

# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.karate_club_graph()

#first compute the best partition
partition = community_louvain.best_partition(G)

# compute the best partition
partition = community_louvain.best_partition(G)

# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()

# %%
G
