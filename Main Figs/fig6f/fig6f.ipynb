# %%
import dot_precent as dp
import pandas as pd
import os,glob,copy

# %%
dfdata = pd.read_excel("Agrp_Pomc_ARH_dot_plot.xlsx",index_col=0)

# %%
# plot for figS6a
plots = ['PAG','MRN','SCm','PB','MEA_contra','CEA_contra','BST','MPN','PVH']
ylist = [1,2,3,4]

dotplot = dp.dot_process(dfdata)
dfper = dotplot.get_pecent_df(hue="cluster",plot_list=plots)
dfval = dotplot.get_mean_value(hue="cluster",plot_list=plots)
dotplot.plot_dot_scatter_hue_y(filepath="Figf.pdf",cmap="Reds",
    # color_bar=False,dot_bar=False,
    color_bar=True,dot_bar=True,
    ylist=ylist,
    max_val = 2000,
    xlabel="Target areas",ylabel="Subtypes",figsize = (0.9*len(plots),9))
