# %%
import dot_precent as dp
import pandas as pd
import os,glob,copy

# %%
dfdata = pd.read_csv("All_neurons_projection_infor&cluster.csv",index_col=0)

# %%
# plot for figS6a new
plots = ["CEA","MEA","BMA","CA1","PA","SNr","CP","GPe","STN","ACA","MO","LH","MD","PVT","MPO","MPN","LPO","ME","ARH","VMH","DMH","BST","LS"]
ylist = [1,5,4,2,3,8,9,6,7,10,11,12,13,14,15]

dotplot = dp.dot_process(dfdata)
dfper = dotplot.get_pecent_df(hue="cluster",plot_list=plots)
dfval = dotplot.get_mean_value(hue="cluster",plot_list=plots)
dotplot.plot_dot_scatter_hue_y(filepath="FigS6a_new.pdf",cmap="Reds",
    # color_bar=False,dot_bar=False,
    color_bar=True,dot_bar=True,
    ylist=ylist,
    max_val = 3000,
    xlabel="Target areas",ylabel="Subtypes",figsize = (0.9*len(plots),11))

# %%
# plot for figS6a
plots = ["MPO","MPN","LPO","ME","ARH","VMH","DMH","BST","LS","CEA","MEA","BMA","CA1","PA","SNr","CP","GPe","STN","ACA","MO","LH","MD","PVT"]
ylist = [1,5,4,2,3,8,9,6,7,10,11,12,13,14,15]

dotplot = dp.dot_process(dfdata)
dfper = dotplot.get_pecent_df(hue="cluster",plot_list=plots)
dfval = dotplot.get_mean_value(hue="cluster",plot_list=plots)
dotplot.plot_dot_scatter_hue_y(filepath="FigS6a.pdf",cmap="Reds",
    # color_bar=False,dot_bar=False,
    color_bar=True,dot_bar=True,
    ylist=ylist,
    max_val = 3000,
    xlabel="Target areas",ylabel="Subtypes",figsize = (0.9*len(plots),13))

# %%
# plot for figS7a
plots = ['PAG','MY','P','AM',"VTN",'VTA','SCm','PGRNl','IRN', 'NTS','PRNc',
 'PRNr','MO','TT','MPO','LPO',"BST","IC",'VMH','RCH','DMH','AHN']

ylist = [20,22,16, 17,  19, 21, 18,23, 24,30, 31, 25, 26, 27, 28, 29]

dotplot = dp.dot_process(dfdata)
dfper = dotplot.get_pecent_df(hue="cluster",plot_list=plots)
dfval = dotplot.get_mean_value(hue="cluster",plot_list=plots)
dotplot.plot_dot_scatter_hue_y(filepath="FigS7a.pdf",cmap="Reds",
    # color_bar=False,dot_bar=False,
    color_bar=True,dot_bar=True,
    ylist=ylist,
    max_val = 3000,
    xlabel="Target areas",ylabel="Subtypes",figsize = (0.9*len(plots),13))
